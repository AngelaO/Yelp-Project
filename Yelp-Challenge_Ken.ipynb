# %% [markdown]
# # Introduction - Yelp Dataset

# %% [markdown]
# #### 1. Set up connection to MongoDB

# %%
import pymongo
import pandas as pd
conn = pymongo.Connection("mongodb://asi-fellow:asi@c402.lamppost.3.mongolayer.com:10402,c520.lamppost.6.mongolayer.com:10520/asi?replicaSet=set-54eb0df990439c3a94000fd5")
print type(conn)
# Out:
# <class 'pymongo.connection.Connection'>

# %%
db = conn['asi']
print db
# Out:
# Database(Connection([u'c402.lamppost.3.mongolayer.com:10402', u'c520.lamppost.6.mongolayer.com:10520']), u'asi')

# %%
db.collection_names()
# Out:
# [u'system.indexes', u'business', u'user', u'checkin', u'tip', u'review']

# %%
businesses = db['business']
users = db['user']
checkins = db['checkin']
tips = db['tip']
reviews = db['review']

# %%
def read_mongo(collection, query={}, limit=3):
    """ Read from Mongo and Store into DataFrame """
    # Collection
    cursor = collection.find(query).limit(limit)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))

    return df

# %% [markdown]
# ###### Brief summary of data...

# %%
print "businesses: ", businesses.count()
print "users: " , users.count()
print "checkins: ", checkins.count()
print "tips: ", tips.count()
print "reviews: ", reviews.count()
# Out:
# businesses:  61184
# users:
# 366715
# checkins:  45166
# tips:
# 495107
# reviews:  1569264

# %% [markdown]
# <hr>

# %% [markdown]
# #### 2. List Yelp Businesses

# %% [markdown]
# ###### Note the values under the 'city' column...

# %%
read_mongo(businesses, {}, 5)
# Out:
#                         _id  \
# 0  54eb2cf9d181ea9cde8f33e7
# 1  54eb2cf9d181ea9cde8f33e8
# 2  54eb2cf9d181ea9cde8f33e9
# 3  54eb2cfad181ea9cde8f33ea
# 4  54eb2cfad181ea9cde8f33eb
#
#                                           attributes             business_id  \
# 0                     {u'By Appointment Only': True}  vcNAWiLM4dR7D2nwwJ7nCA
# 1  {u'Happy Hour': True, u'Accepts Credit Cards':...  UsFtqoBl7naz8AVUBZMjQQ
# 2                           {u'Good for Kids': True}  cE27W9VPgO88Qxe4ol6y_g
# 3                                                 {}  HZdLhv6COCleJMo7nPl-RA
# 4  {u'Alcohol': u'full_bar', u'Noise Level': u'av...  mVHrayjG3uZ_RLHkLj-AMg
#
#                                           categories         city  \
# 0                        [Doctors, Health & Medical]      Phoenix
# 1                                        [Nightlife]   Dravosburg
# 2                     [Active Life, Mini Golf, Golf]  Bethel Park
# ...

# %% [markdown]
# 1) We know we have data for 10 cities across 4 countries.
# U.K.: Edinburgh
# Germany: Karlsruhe
# Canada: Montreal and Waterloo
# U.S.: Pittsburgh, Charlotte, Urbana-Champaign, Phoenix, Las Vegas, Madison
#
# 2) We do not know for certain which city each business is located in
# because the 'city' column in the 'business' table contains not only cities
# (e.g. 'Phoenix', 'Montreal') but also regions and districts (e.g. 'Carnegie',
# 'Arlington', 'Belmont').
#
# Question: How do we know what city a business is located in ?
#
# 3) We know the latitude and longitude of each business.
#
# Therefore, if we cluster the businesses by latitude and longitude
# into 10 clusters, we should be able to segment the businesses
# by cities.
#
# Question: What is the benefit of this?
# Answer: This will enable to us to make comparisons about businesses
# between cities.

# %%
from itertools import permutations
import numpy as np
import sklearn
import sklearn.cluster as clu
import sklearn.datasets as ds
import sklearn.grid_search as gs
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Get all businesses
BusinessesDF = read_mongo(businesses, {}, businesses.count())

# Only print certain columns within a data frame.
print BusinessesDF[['city', 'state', 'latitude', 'longitude']]
# Out:
#               city state   latitude   longitude
# 0          Phoenix    AZ  33.499313 -111.983758
# 1       Dravosburg    PA  40.350519  -79.886930
# 2      Bethel Park    PA  40.356896  -80.015910
# 3       Pittsburgh    PA  40.357620  -80.059980
# 4         Braddock    PA  40.408735  -79.866351
# 5         Carnegie    PA  40.415517  -80.067534
# 6         Carnegie    PA  40.394588  -80.084454
# 7         Carnegie    PA  40.405404  -80.076267
# 8         Carnegie    PA  40.406324  -80.090357
# 9         Carnegie    PA  40.387732  -80.092874
# 10        Carnegie    PA  40.387732  -80.092874
# 11        Carnegie    PA  40.396469  -80.084942
# 12        Carnegie    PA  40.396744  -80.084800
# 13        Carnegie    PA  40.404638  -80.089985
# 14        Carnegie    PA  40.417419  -80.088557
# 15        Carnegie    PA  40.408670  -80.085279
# 16        Carnegie    PA  40.408568  -80.084992
# 17        Carnegie    PA  40.407889  -80.086060
# 18        Carnegie    PA  40.386891  -80.093704
# ...

# %%
# Prepare data for KMeans clustering.

# Init vars
all_coords = []
y = []

# Get coordinates into an 'numpy.ndarray'
# i.e. an n-dimensional numpy array.
coords = array([BusinessesDF['latitude'], BusinessesDF['longitude']])
            
# Manipulate coords
X = array(coords)
X = X.T
y = array(y)

# %%
# Perform KMeans clustering on coordinates, we are expecting 10 clusters,
# one for each city.
km = clu.KMeans(n_clusters=10, n_init=100)
km.fit(X)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=10, n_init=100,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %% [markdown]
# ###### Define utility method to help with plotting.

# %%
def display_clustering(X, y, labels, title):
    """Plot the data points with the cluster
    colors."""

    # Display the points with the true labels on
    # the left, and with the clustering labels on the right.
    for i, (c, title) in enumerate(zip(
            [y, labels], ["True labels", title])):
        Our_plot = plt.scatter(X[:,0], X[:,1], c=c, s=30,
                    linewidths=0,
                    cmap=plt.cm.rainbow)
        plt.gca().invert_xaxis()
        plt.xticks([]); 
        plt.yticks([])
        plt.title(title)

# %%
# Plot the results
# plt.scatter(X[:,1], X[:,0])
display_clustering(X, y, km.labels_, "KMeans(10)")

# %% [markdown]
# ###### Display (a few) cluster labels for points.

# %%
print len(km.labels_), km.labels_
# Out:
# 61184 [3 2 2 ..., 0 0 6]

# %% [markdown]
# ###### Display centre-points of clusters - there should be 10...but we don't know which city each one is.

# %%
print km.cluster_centers_
# Out:
# [[  36.12093325 -115.17494296]
#  [  55.94906702   -3.196246  ]
#  [  40.43692488  -79.97413881]
#  [  33.48477253 -111.98784217]
#  [  45.51025169  -73.59954224]
#  [  43.07898244  -89.40428089]
#  [  49.00326521    8.40178134]
#  [  35.18644904  -80.82900453]
#  [  40.11230246  -88.22888262]
#  [  43.45932018  -80.50607375]]

# %% [markdown]
# <hr>

# %% [markdown]
# #### 3. Use data from Google Maps to add city names to clusters based on latitude and longitude coordinates.

# %%
# Create data frame
CityDF =  pd.DataFrame(list(km.cluster_centers_),columns=['latitude', 'longitude'])


# Need to name our cities
cities = ['',      
          '', 
          '',      
          '', 
          '', 
          '', 
          '', 
          '',
          '',
          '']

# Knowing their countries might be useful too
countries = ['', 
             '', 
             '', 
             '', 
             '', 
             '', 
             '', 
             '', 
             '', 
             '']

# Add new columns to data frame
CityDF.insert(0, 'City', cities)
CityDF.insert(1, 'Country', countries)

print CityDF
# Out:
#   City Country   latitude   longitude
# 0               36.120933 -115.174943
# 1               55.949067   -3.196246
# 2               40.436925  -79.974139
# 3               33.484773 -111.987842
# 4               45.510252  -73.599542
# 5               43.078982  -89.404281
# 6               49.003265    8.401781
# 7               35.186449  -80.829005
# 8               40.112302  -88.228883
# 9               43.459320  -80.506074

# %%
# GoogleMaps lookup table.
# Table of known coordinates of cities
# which we have already looked up on GoogleMaps.
# We have to do this because the index-order of 
# coordinates of cluster centres returned by 'KMeans'
# can vary and may change from run to run.


dfccll = pd.DataFrame({'city' : ['Charlotte', 'Las Vegas', 'Edinburgh', 
                           'Montreal', 'Phoenix', 'Madison', 'Karlsruhe', 
                           'Pittsburgh', 'Urbana-Champaign', 'Waterloo'],
                    'country' : ['USA', 'USA', 'UK', 'Canada', 'USA', 
                                 'USA', 'Germany', 'USA', 'USA', 'Canada'],
                    'latitude' : [35.18644904, 36.12093325, 55.94906702, 45.51025169, 33.48477253,
                                  43.07898244, 49.00326521, 40.43692488, 40.11230246, 43.45932018],
                    'longitude' : [-80.82900453, -115.17494296, -3.196246, -73.59954224, -111.98784217,
                                   -89.40428089, 8.40178134, -79.97413881, -88.22888262, -80.50607375]
                })

print dfccll
# Out:
#                city  country   latitude   longitude
# 0         Charlotte      USA  35.186449  -80.829005
# 1         Las Vegas      USA  36.120933 -115.174943
# 2         Edinburgh       UK  55.949067   -3.196246
# 3          Montreal   Canada  45.510252  -73.599542
# 4           Phoenix      USA  33.484773 -111.987842
# 5           Madison      USA  43.078982  -89.404281
# 6         Karlsruhe  Germany  49.003265    8.401781
# 7        Pittsburgh      USA  40.436925  -79.974139
# 8  Urbana-Champaign      USA  40.112302  -88.228883
# 9          Waterloo   Canada  43.459320  -80.506074

# %%
# Assign correct city and country to each pair or latitude and longitude coordinates.

for index, row in CityDF.iterrows():
    for ccllindex, ccllrow in dfccll.iterrows():
        if (np.isclose(row['latitude'], ccllrow['latitude']) and
            np.isclose(row['longitude'], ccllrow['longitude'])):
            CityDF.loc[index, 'City'] = ccllrow['city'] 
            CityDF.loc[index, 'Country'] = ccllrow['country'] 
    
print CityDF
# Out:
#                City  Country   latitude   longitude
# 0         Las Vegas      USA  36.120933 -115.174943
# 1         Edinburgh       UK  55.949067   -3.196246
# 2        Pittsburgh      USA  40.436925  -79.974139
# 3           Phoenix      USA  33.484773 -111.987842
# 4          Montreal   Canada  45.510252  -73.599542
# 5           Madison      USA  43.078982  -89.404281
# 6         Karlsruhe  Germany  49.003265    8.401781
# 7         Charlotte      USA  35.186449  -80.829005
# 8  Urbana-Champaign      USA  40.112302  -88.228883
# 9          Waterloo   Canada  43.459320  -80.506074

# %%
# Define some utility methods to access city data.

def getCityNameByIndex(index_val):
  return CityDF.iloc[index_val, 0]  

def getCountryByIndex(index_val):
  return CityDF.iloc[index_val, 1]  

def getIndexByCityName(city_name):
    for index, row in CityDF.iterrows():
        if (CityDF.loc[index, 'City'] == city_name):
            return index

# %% [markdown]
# ###### We use the km.predict() method to tell us which cluster a given pair of coordinates belongs to.

# %%
print km.predict([[49.009268, 8.409159]])
# Out:
# [6]

# %%
print km.predict([[40.391255, -80.073426]])
# Out:
# [2]

# %% [markdown]
# ###### Display a few examples of coordinates and the cluster label for each point.

# %%
array2 = array([BusinessesDF['latitude'], BusinessesDF['longitude'], km.labels_])
print array2.T
# Out:
# [[  33.499313  -111.983758     3.       ]
#  [  40.350519   -79.88693      2.       ]
#  [  40.3568962  -80.01591      2.       ]
#  ...,
#  [  36.1226902 -115.1701939    0.       ]
#  [  36.1600724 -115.350056     0.       ]
#  [  49.0092676    8.4091589    6.       ]]

# %% [markdown]
# <hr>

# %% [markdown]
# #### 4. Let's ask a few questions of our data.

# %% [markdown]
# ###### How many businesses do we have in total?

# %%
print businesses.count()
# Out:
# 61184

# %% [markdown]
# ###### How many businesses are in each of our 10 cities?

# %%
labelsList = list(km.labels_)

for index, row in CityDF.iterrows():
    print row['City'], labelsList.count(index)
# Out:
# Las Vegas
# 16490
# Edinburgh
# 3115
# Pittsburgh
# 3041
# Phoenix
# 25231
# Montreal
# 3921
# Madison
# 2309
# Karlsruhe
# 948
# Charlotte
# 5151
# Urbana-Champaign
# 627
# Waterloo
# 351

# %% [markdown]
# ###### We need to relate each business back to it's cluster label - done via latitude/longitude coords.

# %%
# Initialise new empty columns added to data frame
BusinessesDF["clusternumber"] = ""
BusinessesDF["clustercity"] = ""
BusinessesDF["country"] = ""

#print BusinessesDF

# %%
print list(BusinessesDF.columns.values)
# Out:
# [u'_id', u'attributes', u'business_id', u'categories', u'city', u'full_address', u'hours', u'latitude', u'longitude', u'name', u'neighborhoods', u'open', u'review_count', u'stars', u'state', u'type', 'clusternumber', 'clustercity', 'country']

# %%
#
# Add values to the 'clusternumber', 'clustercity' and 'country' columns
# for each record in the businesses collection.
#
for index, row in BusinessesDF.iterrows():
    cnum = km.predict([[row['latitude'], row['longitude']]])
    clist = cnum.tolist()
    cnum = clist[0]
    BusinessesDF.loc[index, 'clusternumber'] = cnum
    BusinessesDF.loc[index, 'clustercity'] = getCityNameByIndex(cnum)
    BusinessesDF.loc[index, 'country'] = getCountryByIndex(cnum)

# %%
# EXPERIMENTAL 
#print BusinessesDF[['latitude','longitude', 'full_address', 'clusternumber', 'clustercity']]
print BusinessesDF[['business_id','categories', 'clustercity']][:3]
# Out:
#               business_id                      categories clustercity
# 0  vcNAWiLM4dR7D2nwwJ7nCA     [Doctors, Health & Medical]     Phoenix
# 1  UsFtqoBl7naz8AVUBZMjQQ                     [Nightlife]  Pittsburgh
# 2  cE27W9VPgO88Qxe4ol6y_g  [Active Life, Mini Golf, Golf]  Pittsburgh

# %%
# Build an inverted index of all business categories and business_ids
categoriesDict = {}

for index, row in BusinessesDF.iterrows():
    cat_list = BusinessesDF.loc[index, 'categories']
    for cat in cat_list:
        if (categoriesDict.has_key(cat)):
            categoriesDict.get(cat).append(BusinessesDF.loc[index, 'business_id'])
        else:
            categoriesDict[cat] = list()
            categoriesDict.get(cat).append(BusinessesDF.loc[index, 'business_id'])

# %% [markdown]
# How many business categories are there?

# %%
print len(categoriesDict)
# Out:
# 783

# %% [markdown]
# Let's look at some business categories...

# %%
# Just look at 10 business categories...  
temp_keys = categoriesDict.keys()  
for x in range(0, 10):
     print temp_keys[x]
# Out:
# Roofing
# Truck Rental
# Drugstores
# Dry Cleaning & Laundry
# Trains
# Buffets
# Boating
# Child Care & Day Care
# Endodontists
# Creperies

# %% [markdown]
# How many businesses come under the category of 'Truck Rental ?

# %%
print len(categoriesDict['Truck Rental'])
# Out:
# 46

# %% [markdown]
# Let's look at the 'business_id' values of businesses that come under the category of 'Truck Rental'

# %%
print "Truck Rental - ", categoriesDict.get('Truck Rental')
# Out:
# Truck Rental -  [u't8Dz2luOZ-4NhT8DPxFdqQ', u'tgGaaLuFPbeiwPZcAKFxGA', u'OasJ_Jq4cUEHvWLa7UoQzQ', u'3Cb6vwHIW8-77TZz0DRpug', u'pYJ7o-LxNZ3K3KUd8d3pXw', u'MBEr_IdOPeaS9X9WvdofKw', u'-h46lMwL-VfUi40kqX4GaA', u'H4Fb9Zs_9Yz-WtwlvMOVXg', u'YOQkOW0SP5WsfL9XFSvXCg', u'flDRr8HD7v6AOEvkfXdpOA', u'dQf8nwN8Dg1oT0J-LS76Wg', u'dXKyDgBp0J2wrpHbICJVSg', u'Eq77oXlux32hgjUCzP83bg', u'nYiZxzy4y9cF-QNbkECweQ', u'zefTdKh-jBegyC0gVHHWSA', u'6NfspCX73CrjDcce3Y5O2A', u'3k66wPhCM30nIkPGcXas7w', u'h5_W6IBTVySDkJHy8oZUdQ', u'QPXmLupGCI7sFfqoDyb_nA', u'9uml3WvQWBVcIKTAht7GbQ', u'wBKo18dDR6rWUfAuOC40fg', u'vf2yCONx3HYVOyJ0ftnv5Q', u'1qw1cml6wPSza3v_PIse1Q', u'1Y_QnWorJI4RzrNiYzuysg', u'sArVtjujwjf3WCV3U9gIkw', u'MIP-qZ2VW2QlMonxe76k3Q', u'ux285TUCPSWJjHuCJFS3NA', u'CEnqR11fktxXudSaz6INoQ', u'vL2TkvmkSb69BQuuJGpdlw', u'M1U2A-3vLFBFKfAWW8UGQA', u'FPuhqyP9Q5OMC_Q5RPhFOw', u'BlmBPGYjOoFL25CXCin75g', u'y3tthh1bytcqjAmh7wMftg', u'r5FiW-EM9WT1aYd68R8f6g', u'Ealot_FO7rSMNUKk9Qk_FA', u'wPriPtODfiaTatTIKkOSqw', u'fNZnHne
# ...

# %% [markdown]
# Let's look at 3 of the businesses listed, and confirm they come under the 'Truck Rental' category.

# %%
# Filter BusinessDF by 'business_id' field.

BusinessesDF[(BusinessesDF.business_id == 't8Dz2luOZ-4NhT8DPxFdqQ') |
             (BusinessesDF.business_id == 'tgGaaLuFPbeiwPZcAKFxGA') |
             (BusinessesDF.business_id == 'OasJ_Jq4cUEHvWLa7UoQzQ') 
             ]
# Out:
#                            _id                       attributes  \
# 1083  54eb2cfed181ea9cde8f3822                               {}
# 1566  54eb2d00d181ea9cde8f3a05  {u'Accepts Credit Cards': True}
# 1702  54eb2d01d181ea9cde8f3a8d  {u'Accepts Credit Cards': True}
#
#                  business_id  \
# 1083  t8Dz2luOZ-4NhT8DPxFdqQ
# 1566  tgGaaLuFPbeiwPZcAKFxGA
# 1702  OasJ_Jq4cUEHvWLa7UoQzQ
#
#                                              categories       city  \
# 1083  [Hotels & Travel, Truck Rental, Car Rental, Au...  Charlotte
# 1566  [Home Services, Movers, Automotive, Truck Rent...    Madison
# 1702  [Local Services, Automotive, Truck Rental, Sel...  Champaign
#
#                                            full_address  \
# 1083  4108 Rental Car Rd\nDouglas Intl Arpt\nCharlot...
# 1566                     22 Atlas Ct\nMadison, WI 53714
# 1702          306 E University Ave\nChampaign, IL 61820
#
#                                                   hours   latitude  longitude  \
# ...

# %% [markdown]
# Let's see how many businesses come into each category - remember a business can belong to more than one category.

# %%
for the_key, the_value in categoriesDict.iteritems():
    print the_key, ' - ', len(the_value)
# Out:
# Roofing  -  35
# Truck Rental  -  46
# Drugstores  -  561
# Dry Cleaning & Laundry  -  425
# Trains  -  2
# Buffets  -  420
# Boating  -  31
# Child Care & Day Care  -  93
# Endodontists  -  26
# Creperies  -  57
# Canadian (New)  -  183
# Business Law  -  12
# Teppanyaki  -  2
# Appliances  -  150
# Occupational Therapy  -  6
# Speech Therapists  -  7
# Pool & Hot Tub Service  -  13
# Comedy Clubs  -  57
# Architects  -  2
# Szechuan  -  26
# Climbing  -  14
# Audiologist  -  3
# Pet Boarding/Pet Sitting  -  255
# Grocery  -  1233
# Pet Adoption  -  7
# Hair Removal  -  439
# Dog Parks  -  53
# Adult Education  -  19
# Stadiums & Arenas  -  73
# Community Service/Non-Profit  -  107
# Bowling  -  77
# Restaurants  -  21892
# DJs  -  35
# Formal Wear  -  43
# Hiking  -  76
# Fabric Stores  -  67
# Bankruptcy Law  -  14
# Outdoor Gear  -  95
# Delis  -  649
# Bed & Breakfast  -  56
# Tanning  -  210
# Halal  -  30
# Cantonese  -  18
# Herbs & Spices  -  17
# ...

# %% [markdown]
# Let's see if we can break down businesses by city and category.
# For example - can we find all the florists in the Pittsburgh area ?

# %%
# Get list of all florists
floristsList = categoriesDict.get('Florists')

# Filter list of all florists to just those in the Pittsburgh area. 
floristsInPittsburgh = BusinessesDF[(BusinessesDF.business_id.isin(floristsList)) & (BusinessesDF.clustercity == 'Pittsburgh')]

# Print count of florists in the Pittsburgh area.
print "There are ", len(floristsInPittsburgh), "florists in the Pittsburgh area."

# Print details of each florist in the Pittsburgh area.
print floristsInPittsburgh[['business_id', 'categories', 'name', 'full_address']]
# Out:
# There are  18 florists in the Pittsburgh area.
#                   business_id  \
# 75     imM-x_nAxVtYGVFJJ4FS3Q
# 248    bufORugql7KgD_d5KvhxDQ
# 251    T6P49PTjPAy7BzyGtscLqw
# 349    jnzSNWoOjBityIjb0tZRSg
# 502    IrI9nBmRKIGFYnnmrHeqtQ
# 533    Ig74RHJuf1DbDmJNWQ-HpQ
# 564    Nc6HP6jO3s2I02sCpIe6rQ
# 8743   2E8PDh_4iBuxhWghx9jdQQ
# 8762   6LbeU_OT1E5MP022PhExvQ
# 8866   hsdckXMCy_Pjsj83ODyhqA
# 8949   dgzQIKq_Vj7maWeqiU7Qtg
# 8971   yFKgnHWkFhp93RxVq1QE7Q
# 23188  H7XCWLhCbRMDtNs6GfEZXQ
# 39532  EWiV5r_ELrqFyMquwLmtZQ
# 43411  GMLbWz9fY-3meEXErnc2Ww
# 45551  b8v_trsFjSEm69NY5k91Zg
# 53417  nZq_D4BLT2J8Uzku1xJQ7A
# 57090  Czs-UJ7reJlE1OJNa5z48A
#
#                                               categories  \
# 75                 [Flowers & Gifts, Shopping, Florists]
# 248    [Shopping, Flowers & Gifts, Nurseries & Garden...
# 251                [Flowers & Gifts, Shopping, Florists]
# 349                [Flowers & Gifts, Shopping, Florists]
# ...

# %% [markdown]
# <hr/>

# %% [markdown]
# ###### Businesses also have 'attributes' assigned to them. Let's see some of these attributes and their values.

# %%
print BusinessesDF[['business_id','attributes']]
# Out:
#                   business_id  \
# 0      vcNAWiLM4dR7D2nwwJ7nCA
# 1      UsFtqoBl7naz8AVUBZMjQQ
# 2      cE27W9VPgO88Qxe4ol6y_g
# 3      HZdLhv6COCleJMo7nPl-RA
# 4      mVHrayjG3uZ_RLHkLj-AMg
# 5      KayYbHCt-RkbGcPdGOThNg
# 6      b12U9TFESStdy7CsTtcOeg
# 7      Sktj1eHQFuVa-M4bgnEh8g
# 8      3ZVKmuK2l7uXPE6lXY4Dbg
# 9      wJr6kSA5dchdgOdwH6dZ2w
# 10     yXuao0pFz1AxB21vJjDf5w
# 11     fNGIbpazjTRdXgwRY_NIXA
# 12     b9WZJp5L1RZr4F1nxclOoQ
# 13     zaXDakTd3RXyOa7sMrUE1g
# 14     zgy27FSnvwdINfk5cXBIyQ
# 15     WETE_LykpcnrC1sFcQ5EGg
# 16     6o3RK6rTcN3nw-j-r2nQmA
# 17     woOVJ0Z2f6XNCDntHA3b_g
# 18     rv7CY8G_XibTx82YhuqQRw
# 19     e_U_FnpdKVgNb4mUN2cU_Q
# 20     SQ0j7bgSTazkVQlF5AnqyQ
# 21     wqu7ILomIOPSduRwoWp4AQ
# 22     1u2NauOy8xDj7aFQET680A
# 23     P1fJb2WQ1mXoiudj8UE44w
# 24     xxWFOD46ubTSF3nPRM19BA
# 25     PK6aSizckHFWk8i0oxt5DA
# 26     sRqB6flj3GtTZIZJQxf_oA
# 27     3gmBc0qN_LtGbZAjTtHWZg
# 28     yHTLTr-QN-loO_7XoxS8qg
# 29     6ilJq_05xRgek_8qUp36-g
# ...

# %%
# Build an inverted index of all business attributes and business_ids
attributesDict = {}

for index, row in BusinessesDF.iterrows():
    attrib_list = BusinessesDF.loc[index, 'attributes']
    for attrib in attrib_list:
        if (attributesDict.has_key(attrib)):
            attributesDict.get(attrib).append(BusinessesDF.loc[index, 'business_id'])
        else:
            attributesDict[attrib] = list()
            attributesDict.get(attrib).append(BusinessesDF.loc[index, 'business_id'])

# %% [markdown]
# How many different business attributes are there ?

# %%
print len(attributesDict)
# Out:
# 38

# %% [markdown]
# Let's take a look at them.

# %%
# Let's look at just 10 business attributes...  
temp_keys = attributesDict.keys()  
for x in range(0, 10):
     print temp_keys[x]
# Out:
# Drive-Thru
# Alcohol
# Open 24 Hours
# Noise Level
# Hair Types Specialized In
# Music
# Has TV
# Attire
# Ambience
# Good for Kids

# %% [markdown]
# How many businesses have a value for the 'Open 24 Hours' attribute ?

# %%
print len(attributesDict['Open 24 Hours'])
# Out:
# 334

# %% [markdown]
# Let's look at some businesses that have the 'Open 24 Hours' attribute.

# %%
print "Open 24 Hours - ", attributesDict.get('Open 24 Hours')[:10]
# Out:
# Open 24 Hours -  [u'BG4N0V93wml9kaU6YYRxRA', u'2X5G4Ujq0s4Wfn4TC7gX0g', u'cmGR1HS9ms233roSllcglw', u'mpDxBBGywUE6GRRKja3sBA', u'hIQRiE3UsYH7UsrsDwJwLA', u'CN6AB-R4OLsKxFhQ1Kk68g', u'i9JeI7bd1qXGi15FoD45GA', u'Hh5lyZtOrS5LKk4YCgj8Kw', u'OxR3b_qcMJlzwzGPU5fmdA', u'e5kc0CQ4R-PCCDgb274gSg']

# %% [markdown]
# Let's look at 3 of the businesses listed, and confirm they have a value for the 'Open 24 Hours' attribute.

# %%
# Filter BusinessDF by 'business_id' field.
 
BusinessesDF[(BusinessesDF.business_id == 'BG4N0V93wml9kaU6YYRxRA') |
             (BusinessesDF.business_id == '2X5G4Ujq0s4Wfn4TC7gX0g') |
             (BusinessesDF.business_id == 'cmGR1HS9ms233roSllcglw') 
             ]
# Out:
#                           _id  \
# 96   54eb2cfad181ea9cde8f3447
# 255  54eb2cfbd181ea9cde8f34e6
# 560  54eb2cfcd181ea9cde8f3617
#
#                                             attributes  \
# 96   {u'Price Range': 2, u'Accepts Credit Cards': T...
# 255  {u'Alcohol': u'beer_and_wine', u'Open 24 Hours...
# 560  {u'Delivery': False, u'Take-out': True, u'Pric...
#
#                 business_id  \
# 96   BG4N0V93wml9kaU6YYRxRA
# 255  2X5G4Ujq0s4Wfn4TC7gX0g
# 560  cmGR1HS9ms233roSllcglw
#
#                                             categories        city  \
# 96               [Food, Grocery, Shopping, Drugstores]  Pittsburgh
# 255     [Pubs, Bars, Hot Dogs, Nightlife, Restaurants]  Pittsburgh
# 560  [Breakfast & Brunch, Creperies, French, Restau...  Pittsburgh
#
#                                           full_address  \
# 96   6320 Shakespeare St\nSte 7\nShadyside\nPittsbu...
# 255          1118 S Braddock Ave\nPittsburgh, PA 15218
# ...

# %% [markdown]
# Let's see how many businesses have each attribute - remember a business can have zero, one or more attributes.

# %%
for the_key, the_value in attributesDict.iteritems():
    print the_key, ' - ', len(the_value)
# Out:
# Drive-Thru  -  2569
# Alcohol  -  20457
# Open 24 Hours  -  334
# Noise Level  -  18519
# Hair Types Specialized In  -  326
# Music  -  3700
# Has TV  -  19338
# Attire  -  20390
# Ambience  -  18547
# Good for Kids  -  25371
# Price Range  -  41694
# BYOB  -  866
# Accepts Insurance  -  458
# Good For Dancing  -  3581
# Delivery  -  19924
# Dogs Allowed  -  3591
# Coat Check  -  3699
# Payment Types  -  42
# Smoking  -  4088
# Accepts Credit Cards  -  45072
# BYOB/Corkage  -  1315
# Take-out  -  20300
# Ages Allowed  -  235
# Corkage  -  655
# Happy Hour  -  3728
# Wheelchair Accessible  -  19527
# Outdoor Seating  -  23033
# Takes Reservations  -  19801
# Waiter Service  -  18863
# Wi-Fi  -  17898
# Dietary Restrictions  -  175
# Caters  -  13116
# Order at Counter  -  384
# Good For  -  19288
# Parking  -  37967
# By Appointment Only  -  7922
# Good For Kids  -  2345
# Good For Groups  -  22406

# %% [markdown]
# So far we have only examined whether a business for the presence of an attribute, we have said nothing about the value of the attribute itself. Let's see if we can query businesses by attribute value.

# %%
# Get list of all businesses with the 'Open 24 Hours' attribute.
# We do not know what value the attribute may have. 
open24HoursList = attributesDict.get('Open 24 Hours')

# %% [markdown]
# Let's look at the values for a few cities, say 'Pittsburgh', 'Edinburgh' and 'Las Vegas'.

# %%
# Filter list of all businesses to just those in the Pittsburgh, Edinburgh, and Las Vegas areas. 
open24HoursInPittsburgh = BusinessesDF[(BusinessesDF.business_id.isin(open24HoursList)) & (BusinessesDF.clustercity == 'Pittsburgh')]
open24HoursInEdinburgh = BusinessesDF[(BusinessesDF.business_id.isin(open24HoursList)) & (BusinessesDF.clustercity == 'Edinburgh')]
open24HoursInLasVegas = BusinessesDF[(BusinessesDF.business_id.isin(open24HoursList)) & (BusinessesDF.clustercity == 'Las Vegas')]

# %%
# How many businesses do we have in total in the Pittsburgh area?
print len(BusinessesDF[(BusinessesDF.clustercity == 'Pittsburgh')])
# Out:
# 3041

# %%
# How many businesses in the Pittsburgh area have the 'Open 24 Hours' attribute set?
print len(open24HoursInPittsburgh)
# Out:
# 20

# %%
# define some utility methods

# Select businesses with an attribute regardless of value
def selectBusinessByAttribute(datasetDF, attrib_key):
    resultsList = list()

    for index, row in datasetDF.iterrows():
        attrib_list = datasetDF.loc[index, 'attributes']
        if (attrib_list.has_key(attrib_key)):
            resultsList.append(row)    
            
    return pd.DataFrame(resultsList) 

# Select businesses with an attribute and a specific value
def selectBusinessByAttributeAndValue(datasetDF, attrib_key, attrib_value):
    resultsList = list()

    for index, row in datasetDF.iterrows():
        attrib_list = datasetDF.loc[index, 'attributes']
        if (attrib_list.has_key(attrib_key)) & (attrib_list[attrib_key] == attrib_value):
            resultsList.append(row)    
            
    return pd.DataFrame(resultsList)

# %%
# How many businesses in the Pittsburgh area have the 'Open 24 Hours' attribute?
len(selectBusinessByAttribute(open24HoursInPittsburgh, "Open 24 Hours"))
# Out:
# 20

# %%
# Display them
selectBusinessByAttribute(open24HoursInPittsburgh, "Open 24 Hours")
# Out:
#                             _id  \
# 96     54eb2cfad181ea9cde8f3447
# 255    54eb2cfbd181ea9cde8f34e6
# 560    54eb2cfcd181ea9cde8f3617
# 8628   54eb2d1ed181ea9cde8f559b
# 8660   54eb2d1ed181ea9cde8f55bb
# 8757   54eb2d1fd181ea9cde8f561c
# 8791   54eb2d1fd181ea9cde8f563e
# 8889   54eb2d1fd181ea9cde8f56a0
# 8907   54eb2d1fd181ea9cde8f56b2
# 8983   54eb2d20d181ea9cde8f56fe
# 9015   54eb2d20d181ea9cde8f571e
# 15786  54eb2d3dd181ea9cde8f7191
# 15790  54eb2d3dd181ea9cde8f7195
# 16340  54eb2d3fd181ea9cde8f73bb
# 17169  54eb2d42d181ea9cde8f76f8
# 17247  54eb2d43d181ea9cde8f7746
# 22226  54eb2d57d181ea9cde8f8ab9
# 22916  54eb2d59d181ea9cde8f8d6b
# 22949  54eb2d5ad181ea9cde8f8d8c
# 41503  54eb2da3d181ea9cde8fd606
#
#                                               attributes  \
# 96     {u'Price Range': 2, u'Accepts Credit Cards': T...
# 255    {u'Alcohol': u'beer_and_wine', u'Open 24 Hours...
# 560    {u'Delivery': False, u'Take-out': True, u'Pric...
# ...

# %%
# How many businesses in the Pittsburgh area have the 'Open 24 Hours' attribute set to 'True'? 
len(selectBusinessByAttributeAndValue(open24HoursInPittsburgh, "Open 24 Hours", True))
# Out:
# 1

# %% [markdown]
# It seems there is only 1 business in the Pittsburgh area with an 'Open 24 Hours' attribute set to 'True', so let's look at it.

# %%
selectBusinessByAttributeAndValue(open24HoursInPittsburgh, "Open 24 Hours", True)
# Out:
#                             _id  \
# 41503  54eb2da3d181ea9cde8fd606
#
#                                               attributes  \
# 41503  {u'Take-out': True, u'Accepts Credit Cards': T...
#
#                   business_id                         categories        city  \
# 41503  R9Tll6IKpJtYcsbEv7edCA  [Breakfast & Brunch, Restaurants]  Pittsburgh
#
#                                             full_address  \
# 41503  4656 Browns Hill Rd\nSquirrel Hill\nPittsburgh...
#
#                                                    hours  latitude  longitude  \
# 41503  {u'Monday': {u'close': u'06:00', u'open': u'06...  40.41446 -79.923053
#
#        name               neighborhoods  open  review_count  stars state  \
# 41503  IHOP  [Squirrel Hill, Hazelwood]  True            32    2.5    PA
#
#            type  clusternumber clustercity country
# 41503  business              2  Pittsburgh     USA

# %% [markdown]
# There is only 1 business in the Pittsburgh area with an 'Open 24 Hours' attribute set to 'True'. How many are in Edinburgh and Las Vegas ?

# %%
len(selectBusinessByAttributeAndValue(open24HoursInEdinburgh, "Open 24 Hours", True))
# Out:
# 0

# %%
len(selectBusinessByAttributeAndValue(open24HoursInLasVegas, "Open 24 Hours", True))
# Out:
# 23

# %% [markdown]
# Aggregated results summary for 'Las Vegas'.

# %%
#"Total number of businesses we have in Las Vegas:",
print len(BusinessesDF[(BusinessesDF.clustercity == 'Las Vegas')])

#"How many businesses in the Las Vegas area have the 'Open 24 Hours' attribute? ",
print len(selectBusinessByAttribute(open24HoursInLasVegas, "Open 24 Hours"))

# "How many businesses in the Las Vegas area have the 'Open 24 Hours' attribute set to 'True'?",
print len(selectBusinessByAttributeAndValue(open24HoursInLasVegas, "Open 24 Hours", True))

# "How many businesses in the Las Vegas area have the 'Open 24 Hours' attribute set to 'False'?",
print len(selectBusinessByAttributeAndValue(open24HoursInLasVegas, "Open 24 Hours", False))
# Out:
# 16490
# 113
# 23
# 90

# %%
# Return the value for an attribute for a given businessID.
def getBusinessAttributeValue(businessID, attrib_key):

    datasetDF = BusinessesDF[(BusinessesDF.business_id == businessID)]
    resultsList = list()
    
    for index, row in datasetDF.iterrows():
        attrib_list = datasetDF.loc[index, 'attributes']
        if (attrib_list.has_key(attrib_key)):
            resultsList.append(attrib_list[attrib_key])    

        return resultsList

# %% [markdown]
# <hr>Let's query some business attributes directly.

# %%
print getBusinessAttributeValue('R9Tll6IKpJtYcsbEv7edCA', 'Accepts Credit Cards')
# Out:
# [True]

# %%
print getBusinessAttributeValue('Z94doPdgyDOgjtYUVRBNjQ', 'Alcohol')
# Out:
# [u'none']

# %%
print getBusinessAttributeValue('cmGR1HS9ms233roSllcglw', 'Delivery')
# Out:
# [False]

# %% [markdown]
# As a final business attributes search, let's find all the businesses in Edinburgh that have an 'Alcohol' attribute setting of 'full_bar'.

# %%
alcoholList = attributesDict.get('Alcohol')
alcoholInEdinburgh = BusinessesDF[(BusinessesDF.business_id.isin(alcoholList)) & (BusinessesDF.clustercity == 'Edinburgh')]
alcoholFullBarInEdinburgh = selectBusinessByAttributeAndValue(alcoholInEdinburgh, "Alcohol", 'full_bar')

# %%
print alcoholFullBarInEdinburgh
# Out:
#                             _id  \
# 27259  54eb2d6bd181ea9cde8f9e62
# 27261  54eb2d6bd181ea9cde8f9e64
# 27263  54eb2d6bd181ea9cde8f9e66
# 27264  54eb2d6bd181ea9cde8f9e67
# 27273  54eb2d6bd181ea9cde8f9e70
# 27274  54eb2d6bd181ea9cde8f9e71
# 27276  54eb2d6bd181ea9cde8f9e73
# 27279  54eb2d6bd181ea9cde8f9e76
# 27281  54eb2d6bd181ea9cde8f9e78
# 27282  54eb2d6bd181ea9cde8f9e79
# 27283  54eb2d6bd181ea9cde8f9e7a
# 27284  54eb2d6bd181ea9cde8f9e7b
# 27285  54eb2d6bd181ea9cde8f9e7c
# 27287  54eb2d6bd181ea9cde8f9e7e
# 27288  54eb2d6bd181ea9cde8f9e7f
# 27289  54eb2d6bd181ea9cde8f9e80
# 27295  54eb2d6bd181ea9cde8f9e86
# 27297  54eb2d6bd181ea9cde8f9e88
# 27298  54eb2d6bd181ea9cde8f9e89
# 27300  54eb2d6bd181ea9cde8f9e8b
# 27303  54eb2d6bd181ea9cde8f9e8e
# 27304  54eb2d6bd181ea9cde8f9e8f
# 27305  54eb2d6bd181ea9cde8f9e90
# 27308  54eb2d6bd181ea9cde8f9e93
# 27310  54eb2d6bd181ea9cde8f9e95
# 27317  54eb2d6bd181ea9cde8f9e9c
# 27318  54eb2d6bd181ea9cde8f9e9d
# 27320  54eb2d6bd181ea9cde8f9e9f
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# Reviews.

# %%
# Get all reviews
reviewsDF = read_mongo(reviews, {}, reviews.count())

# %%
# NOTE: Number of reviews = 1569264
